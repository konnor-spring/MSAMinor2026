# %%
"""
============================================================
  CNN vs. Regular Neural Network — Classroom Demo
  Dataset: Fashion-MNIST (10 classes, 70,000 28×28 grayscale images)
============================================================

What this script shows
-----------------------
1. A plain "Dense / Fully-Connected" Neural Network (NN)
   • Every pixel is flattened into a 1-D vector.
   • The network has no idea that neighbouring pixels are related.

2. A Convolutional Neural Network (CNN)
   • Uses Conv2D + MaxPooling layers to learn *local* spatial patterns.
   • Far fewer trainable parameters per layer, yet much better accuracy.

Both models are trained for the same number of epochs so the
comparison is fair.  After training, a summary table and two
side-by-side accuracy/loss plots are displayed.
"""

import time
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# ──────────────────────────────────────────────
#  0.  Reproducibility
# ──────────────────────────────────────────────
tf.random.set_seed(42)
np.random.seed(42)

# ──────────────────────────────────────────────
#  1.  Load & pre-process Fashion-MNIST
# ──────────────────────────────────────────────
print("\n📦  Loading Fashion-MNIST dataset …")
(x_train, y_train), (x_test, y_test) = keras.datasets.fashion_mnist.load_data()

CLASS_NAMES = [
    "T-shirt", "Trouser", "Pullover", "Dress", "Coat",
    "Sandal",  "Shirt",   "Sneaker",  "Bag",   "Boot"
]
NUM_CLASSES = 10
EPOCHS      = 100       # increase for better accuracy; keep low for a quick demo
BATCH_SIZE  = 128

# Normalise pixel values to [0, 1]
x_train = x_train.astype("float32") / 255.0
x_test  = x_test.astype("float32")  / 255.0

# Fashion-MNIST is (N, 28, 28) — add channel dim → (N, 28, 28, 1) for Conv2D
x_train = x_train[..., np.newaxis]
x_test  = x_test[...,  np.newaxis]

# Labels → one-hot
y_train_oh = keras.utils.to_categorical(y_train, NUM_CLASSES)
y_test_oh  = keras.utils.to_categorical(y_test,  NUM_CLASSES)

print(f"   Training samples : {len(x_train):,}")
print(f"   Test samples     : {len(x_test):,}")
print(f"   Image shape      : {x_train.shape[1:]}")
# Out:
# 📦  Loading Fashion-MNIST dataset …
#    Training samples : 60,000
#    Test samples     : 10,000
#    Image shape      : (28, 28, 1)

# %%
# ──────────────────────────────────────────────
#  2.  Dataset preview
# ──────────────────────────────────────────────
fig, axes = plt.subplots(2, 8, figsize=(16, 5))
fig.suptitle("Fashion-MNIST — Sample Images", fontsize=14, fontweight="bold")
indices = np.random.choice(len(x_train), 16, replace=False)
for ax, idx in zip(axes.flat, indices):
    ax.imshow(x_train[idx].squeeze(), cmap="gray")
    ax.set_title(CLASS_NAMES[int(y_train[idx])], fontsize=8)
    ax.axis("off")
plt.tight_layout()
plt.savefig("fashion_mnist_samples.png", dpi=120)
plt.show()
print("\n🖼   Sample grid saved → fashion_mnist_samples.png")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[7], line 12
#       8     ax.imshow(x_train[idx].squeeze(), cmap="gray")
#       9     ax.set_title(CLASS_NAMES[int(y_train[idx])], fontsize=8)
#      10     ax.axis("off")
#      11 plt.tight_layout()
# ---> 12 plt.savefig("fashion_mnist_samples.png", dpi=120)
#      13 plt.show()
#      14 print("\n🖼   Sample grid saved → fashion_mnist_samples.png")
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\pyplot.py:1346, in savefig(fname, **kwargs)
#    1343 fig = gcf()
#    1344 # savefig default implementation has no return, so mypy is unhappy
#    1345 # presumably this is here because subclasses can return?
# -> 1346 res = fig.savefig(fname, **kwargs)  # type: ignore[func-returns-value]
#    1347 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1348 return res
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\figure.py:3515, in Figure.savefig(self, fname, transparent, **kwargs)
#    3513     for ax in self.axes:
#    3514         _recursively_make_axes_transparent(stack, ax)
# -> 3515 self.canvas.print_figure(fname, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\backend_bases.py:2281, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2277 try:
#    2278     # _get_renderer may change the figure dpi (as vector formats
#    2279     # force the figure dpi to 72), so we need to set it again here.
#    2280     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2281         result = print_method(
#    2282             filename,
#    2283             facecolor=facecolor,
#    2284             edgecolor=edgecolor,
#    2285             orientation=orientation,
#    2286             bbox_inches_restore=_bbox_inches_restore,
#    2287             **kwargs)
#    2288 finally:
#    2289     if bbox_inches and restore_bbox:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\backend_bases.py:2138, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2134     optional_kws = {  # Passed by print_figure for other renderers.
#    2135         "dpi", "facecolor", "edgecolor", "orientation",
#    2136         "bbox_inches_restore"}
#    2137     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2138     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2139         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2140 else:  # Let third-parties do as they see fit.
#    2141     print_method = meth
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\backends\backend_agg.py:537, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     490 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     491     """
#     492     Write the figure to a PNG file.
#     493
#    (...)    535         *metadata*, including the default 'Software' key.
#     536     """
# --> 537     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\backends\backend_agg.py:486, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     481 """
#     482 Draw the canvas, then save it using `.image.imsave` (to which
#     483 *pil_kwargs* and *metadata* are forwarded).
#     484 """
#     485 FigureCanvasAgg.draw(self)
# --> 486 mpl.image.imsave(
#     487     filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     488     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\image.py:1722, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1720 pil_kwargs.setdefault("format", format)
#    1721 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1722 image.save(fname, **pil_kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\PIL\Image.py:2708, in Image.save(self, fp, format, **params)
#    2706         fp = builtins.open(filename, "r+b")
#    2707     else:
# -> 2708         fp = builtins.open(filename, "w+b")
#    2709 else:
#    2710     fp = cast(IO[bytes], fp)
#
# PermissionError: [Errno 13] Permission denied: 'fashion_mnist_samples.png'

# %%
# ──────────────────────────────────────────────
#  3.  Model A — Regular (Dense) Neural Network
# ──────────────────────────────────────────────
print("\n" + "="*60)
print("  MODEL A  —  Regular (Fully-Connected) Neural Network")
print("="*60)

def build_regular_nn(input_shape, num_classes):
    """
    A standard multi-layer perceptron.
    The input image is FLATTENED first — all spatial structure is lost.
    """
    model = keras.Sequential([
        # ── Input ──────────────────────────────────────────────────
        layers.Input(shape=input_shape),

        # Flatten 32×32×3 → 3072 values (spatial info discarded!)
        layers.Flatten(),

        # ── Hidden layers ──────────────────────────────────────────
        layers.Dense(512, activation="relu"),
        layers.Dropout(0.3),

        layers.Dense(256, activation="relu"),
        layers.Dropout(0.3),

        layers.Dense(128, activation="relu"),
        layers.Dropout(0.3),

        # ── Output ─────────────────────────────────────────────────
        layers.Dense(num_classes, activation="softmax"),
    ], name="Regular_NN")
    return model
# Out:
# ============================================================
#   MODEL A  —  Regular (Fully-Connected) Neural Network
# ============================================================

# %%
nn_model = build_regular_nn(x_train.shape[1:], NUM_CLASSES)
nn_model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)
nn_model.summary()

print("\n⏱   Training Regular NN …")
t0 = time.time()
nn_history = nn_model.fit(
    x_train, y_train_oh,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_split=0.1,
    verbose=1,
)
nn_train_time = time.time() - t0

nn_loss, nn_acc = nn_model.evaluate(x_test, y_test_oh, verbose=0)
print(f"\n✅  Regular NN  — Test accuracy: {nn_acc:.4f}  |  Test loss: {nn_loss:.4f}")
# Out:
# Model: "Regular_NN"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_2 (Flatten)             │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 512)            │       401,920 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 567,434 (2.16 MB)
#  Trainable params: 567,434 (2.16 MB)
#  Non-trainable params: 0 (0.00 B)
# ⏱   Training Regular NN …
# Epoch 1/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7704 - loss: 0.6333 - val_accuracy: 0.8417 - val_loss: 0.4292
# Epoch 2/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8402 - loss: 0.4420 - val_accuracy: 0.8607 - val_loss: 0.3892
# Epoch 3/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8556 - loss: 0.4009 - val_accuracy: 0.8718 - val_loss: 0.3512
# Epoch 4/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8640 - loss: 0.3779 - val_accuracy: 0.8722 - val_loss: 0.3519
# Epoch 5/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8676 - loss: 0.3634 - val_accuracy: 0.8788 - val_loss: 0.3365
# Epoch 6/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8736 - loss: 0.3448 - val_accuracy: 0.8725 - val_loss: 0.3389
# Epoch 7/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8775 - loss: 0.3362 - val_accuracy: 0.8800 - val_loss: 0.3324
# Epoch 8/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8820 - loss: 0.3237 - val_accuracy: 0.8825 - val_loss: 0.3326
# Epoch 9/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8843 - loss: 0.3168 - val_accuracy: 0.8847 - val_loss: 0.3277
# Epoch 10/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8869 - loss: 0.3065 - val_accuracy: 0.8837 - val_loss: 0.3248
# Epoch 11/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8888 - loss: 0.3016 - val_accuracy: 0.8867 - val_loss: 0.3194
# Epoch 12/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8896 - loss: 0.2962 - val_accuracy: 0.8852 - val_loss: 0.3246
# Epoch 13/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8922 - loss: 0.2932 - val_accuracy: 0.8857 - val_loss: 0.3147
# Epoch 14/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8950 - loss: 0.2869 - val_accuracy: 0.8895 - val_loss: 0.3092
# Epoch 15/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8969 - loss: 0.2784 - val_accuracy: 0.8845 - val_loss: 0.3271
# Epoch 16/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8972 - loss: 0.2769 - val_accuracy: 0.8870 - val_loss: 0.3177
# Epoch 17/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8982 - loss: 0.2727 - val_accuracy: 0.8875 - val_loss: 0.3115
# Epoch 18/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8992 - loss: 0.2701 - val_accuracy: 0.8888 - val_loss: 0.3085
# Epoch 19/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9027 - loss: 0.2639 - val_accuracy: 0.8910 - val_loss: 0.3059
# Epoch 20/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9021 - loss: 0.2591 - val_accuracy: 0.8868 - val_loss: 0.3243
# Epoch 21/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9041 - loss: 0.2581 - val_accuracy: 0.8907 - val_loss: 0.3095
# Epoch 22/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9050 - loss: 0.2558 - val_accuracy: 0.8938 - val_loss: 0.3031
# Epoch 23/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9060 - loss: 0.2542 - val_accuracy: 0.8925 - val_loss: 0.3134
# Epoch 24/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9073 - loss: 0.2474 - val_accuracy: 0.8947 - val_loss: 0.3119
# Epoch 25/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9078 - loss: 0.2474 - val_accuracy: 0.8958 - val_loss: 0.3085
# Epoch 26/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9081 - loss: 0.2453 - val_accuracy: 0.8933 - val_loss: 0.3024
# Epoch 27/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9107 - loss: 0.2413 - val_accuracy: 0.8928 - val_loss: 0.3175
# Epoch 28/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9119 - loss: 0.2375 - val_accuracy: 0.8930 - val_loss: 0.3123
# Epoch 29/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9116 - loss: 0.2349 - val_accuracy: 0.8942 - val_loss: 0.3062
# Epoch 30/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9132 - loss: 0.2322 - val_accuracy: 0.8933 - val_loss: 0.3257
# Epoch 31/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9151 - loss: 0.2290 - val_accuracy: 0.8942 - val_loss: 0.3058
# Epoch 32/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.
# Epoch 73/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9369 - loss: 0.1691 - val_accuracy: 0.8953 - val_loss: 0.3595
# Epoch 74/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9371 - loss: 0.1701 - val_accuracy: 0.8940 - val_loss: 0.3557
# Epoch 75/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9377 - loss: 0.1648 - val_accuracy: 0.8952 - val_loss: 0.3677
# Epoch 76/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9383 - loss: 0.1669 - val_accuracy: 0.9002 - val_loss: 0.3431
# Epoch 77/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9375 - loss: 0.1661 - val_accuracy: 0.8972 - val_loss: 0.3477
# Epoch 78/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9399 - loss: 0.1617 - val_accuracy: 0.8955 - val_loss: 0.3711
# Epoch 79/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9365 - loss: 0.1690 - val_accuracy: 0.8973 - val_loss: 0.3599
# Epoch 80/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9394 - loss: 0.1629 - val_accuracy: 0.8953 - val_loss: 0.3713
# Epoch 81/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9397 - loss: 0.1610 - val_accuracy: 0.9012 - val_loss: 0.3509
# Epoch 82/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9391 - loss: 0.1623 - val_accuracy: 0.8983 - val_loss: 0.3700
# Epoch 83/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9411 - loss: 0.1564 - val_accuracy: 0.8967 - val_loss: 0.3688
# Epoch 84/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9395 - loss: 0.1619 - val_accuracy: 0.8977 - val_loss: 0.3628
# Epoch 85/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9402 - loss: 0.1626 - val_accuracy: 0.8980 - val_loss: 0.3592
# Epoch 86/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9398 - loss: 0.1606 - val_accuracy: 0.8962 - val_loss: 0.3553
# Epoch 87/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9413 - loss: 0.1558 - val_accuracy: 0.9015 - val_loss: 0.3564
# Epoch 88/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9403 - loss: 0.1584 - val_accuracy: 0.8973 - val_loss: 0.3560
# Epoch 89/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9429 - loss: 0.1530 - val_accuracy: 0.8987 - val_loss: 0.3574
# Epoch 90/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9428 - loss: 0.1542 - val_accuracy: 0.8975 - val_loss: 0.3863
# Epoch 91/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9431 - loss: 0.1545 - val_accuracy: 0.8995 - val_loss: 0.3533
# Epoch 92/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9424 - loss: 0.1542 - val_accuracy: 0.8973 - val_loss: 0.3697
# Epoch 93/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9415 - loss: 0.1539 - val_accuracy: 0.8980 - val_loss: 0.3819
# Epoch 94/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9435 - loss: 0.1505 - val_accuracy: 0.9003 - val_loss: 0.3655
# Epoch 95/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9442 - loss: 0.1510 - val_accuracy: 0.8998 - val_loss: 0.3666
# Epoch 96/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9433 - loss: 0.1514 - val_accuracy: 0.9000 - val_loss: 0.3624
# Epoch 97/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9445 - loss: 0.1520 - val_accuracy: 0.8987 - val_loss: 0.3682
# Epoch 98/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9448 - loss: 0.1460 - val_accuracy: 0.8970 - val_loss: 0.3941
# Epoch 99/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9453 - loss: 0.1452 - val_accuracy: 0.9033 - val_loss: 0.3702
# Epoch 100/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9441 - loss: 0.1498 - val_accuracy: 0.8980 - val_loss: 0.3791
#
# ✅  Regular NN  — Test accuracy: 0.9002  |  Test loss: 0.3808

# %%
# ──────────────────────────────────────────────
#  4.  Model B — Convolutional Neural Network
# ──────────────────────────────────────────────
print("\n" + "="*60)
print("  MODEL B  —  Convolutional Neural Network (CNN)")
print("="*60)

def build_cnn(input_shape, num_classes):
    """
    A CNN uses small filters (kernels) that slide across the image,
    detecting edges, textures, and shapes — preserving spatial context.
    Max-pooling then downsamples the feature maps progressively.
    """
    model = keras.Sequential([
        # ── Input ──────────────────────────────────────────────────
        layers.Input(shape=input_shape),

        # ── Convolutional Block 1 ───────────────────────────────────
        # 32 filters, each 3×3  — learns low-level features (edges)
        layers.Conv2D(32, (3, 3), padding="same", activation="relu"),
        layers.Conv2D(32, (3, 3), padding="same", activation="relu"),
        layers.MaxPooling2D(pool_size=(2, 2)),   # 32×32 → 16×16
        layers.Dropout(0.25),

        # ── Convolutional Block 2 ───────────────────────────────────
        # 64 filters — learns mid-level patterns (curves, corners)
        layers.Conv2D(64, (3, 3), padding="same", activation="relu"),
        layers.Conv2D(64, (3, 3), padding="same", activation="relu"),
        layers.MaxPooling2D(pool_size=(2, 2)),   # 16×16 → 8×8
        layers.Dropout(0.25),

        # ── Convolutional Block 3 ───────────────────────────────────
        # 128 filters — learns high-level features (object parts)
        layers.Conv2D(128, (3, 3), padding="same", activation="relu"),
        layers.MaxPooling2D(pool_size=(2, 2)),   # 8×8 → 4×4
        layers.Dropout(0.25),

        # ── Classifier Head ─────────────────────────────────────────
        layers.Flatten(),
        layers.Dense(256, activation="relu"),
        layers.Dropout(0.5),
        layers.Dense(num_classes, activation="softmax"),
    ], name="CNN")
    return model

cnn_model = build_cnn(x_train.shape[1:], NUM_CLASSES)
cnn_model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)
cnn_model.summary()

print("\n⏱   Training CNN …")
t0 = time.time()
cnn_history = cnn_model.fit(
    x_train, y_train_oh,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_split=0.1,
    verbose=1,
)
cnn_train_time = time.time() - t0

cnn_loss, cnn_acc = cnn_model.evaluate(x_test, y_test_oh, verbose=0)
print(f"\n✅  CNN  — Test accuracy: {cnn_acc:.4f}  |  Test loss: {cnn_loss:.4f}")
# Out:
# ============================================================
#   MODEL B  —  Convolutional Neural Network (CNN)
# ============================================================
# Model: "CNN"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 28, 28, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 28, 28, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 14, 14, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 14, 14, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 14, 14, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 14, 14, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 7, 7, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 7, 7, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 7, 7, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 3, 3, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 3, 3, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_3 (Flatten)             │ (None, 1152)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 256)            │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 436,586 (1.67 MB)
#  Trainable params: 436,586 (1.67 MB)
#  Non-trainable params: 0 (0.00 B)
# ⏱   Training CNN …
# Epoch 1/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 12s 26ms/step - accuracy: 0.7467 - loss: 0.6827 - val_accuracy: 0.8547 - val_loss: 0.3813
# Epoch 2/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - accuracy: 0.8561 - loss: 0.3897 - val_accuracy: 0.8875 - val_loss: 0.2978
# Epoch 3/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 14s 33ms/step - accuracy: 0.8802 - loss: 0.3267 - val_accuracy: 0.9012 - val_loss: 0.2600
# Epoch 4/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 15s 35ms/step - accuracy: 0.8936 - loss: 0.2924 - val_accuracy: 0.9090 - val_loss: 0.2393
# Epoch 5/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 15s 36ms/step - accuracy: 0.8990 - loss: 0.2752 - val_accuracy: 0.9123 - val_loss: 0.2305
# Epoch 6/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 15s 36ms/step - accuracy: 0.9065 - loss: 0.2541 - val_accuracy: 0.9190 - val_loss: 0.2260
# Epoch 7/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 14s 33ms/step - accuracy: 0.9120 - loss: 0.2413 - val_accuracy: 0.9230 - val_loss: 0.2131
# Epoch 8/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 14s 34ms/step - accuracy: 0.9156 - loss: 0.2292 - val_accuracy: 0.9233 - val_loss: 0.2055
# Epoch 9/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 14s 34ms/step - accuracy: 0.9188 - loss: 0.2200 - val_accuracy: 0.9257 - val_loss: 0.2053
# Epoch 10/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 14s 33ms/step - accuracy: 0.9214 - loss: 0.2142 - val_accuracy: 0.9235 - val_loss: 0.1989
# Epoch 11/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 14s 32ms/step - accuracy: 0.9244 - loss: 0.2052 - val_accuracy: 0.9273 - val_loss: 0.1964
# Epoch 12/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 26s 63ms/step - accuracy: 0.9265 - loss: 0.1977 - val_accuracy: 0.9303 - val_loss: 0.1887
# Epoch 13/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 14s 33ms/step - accuracy: 0.9273 - loss: 0.1915 - val_accuracy: 0.9295 - val_loss: 0.1922
# Epoch 14/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 14s 33ms/step - accuracy: 0.9302 - loss: 0.1878 - val_accuracy: 0.9312 - val_loss: 0.1919
# Epoch 15/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 21s 49ms/step - accuracy: 0.9320 - loss: 0.1818 - val_accuracy: 0.9287 - val_loss: 0.1966
# Epoch 16/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 34s 80ms/step - accuracy: 0.9338 - loss: 0.1788 - val_accuracy: 0.9303 - val_loss: 0.1916
# Epoch 17/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 14s 33ms/step - accuracy: 0.9354 - loss: 0.1748 - val_accuracy: 0.9323 - val_loss: 0.1901
# Epoch 18/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 14s 32ms/step - accuracy: 0.9367 - loss: 0.1707 - val_accuracy: 0.9338 - val_loss: 0.1828
# Epoch 19/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 15s 36ms/step - accuracy: 0.9387 - loss: 0.1659 - val_accuracy: 0.9318 - val_loss: 0.1882
# Epoch 20/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 25s 59ms/step - accuracy: 0.9382 - loss: 0.1646 - val_accuracy: 0.9337 - val_loss: 0.1906
# Epoch 21/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 38s 89ms/step - accuracy: 0.9398 - loss: 0.1617 - val_accuracy: 0.9345 - val_loss: 0.1865
# Epoch 22/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - accuracy: 0.9408 - loss: 0.1555 - val_accuracy: 0.9357 - val_loss: 0.1871
# Epoch 23/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 14s 33ms/step - accuracy: 0.9424 - loss: 0.1526 - val_accuracy: 0.9350 - val_loss: 0.1902
# Epoch 24/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 13s 31ms/step - accuracy: 0.9431 - loss: 0.1500 - val_accuracy: 0.9365 - val_loss: 0.1826
# Epoch 25/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 13s 31ms/step - accuracy: 0.9446 - loss: 0.1497 - val_accuracy: 0.9320 - val_loss: 0.1968
# Epoch 26/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 13s 31ms/step - accuracy: 0.9455 - loss: 0.1483 - val_accuracy: 0.9367 - val_loss: 0.1817
# Epoch 27/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 13s 31ms/step - accuracy: 0.9450 - loss: 0.1461 - val_accuracy: 0.9367 - val_loss: 0.1863
# Epoch 28/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 14s 32ms/step - accuracy: 0.9459 - loss: 0.1414 - val_accuracy: 0.9387 - val_loss: 0.1867
# Epoch 29/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 13s 31ms/step - accuracy: 0.9481 - loss: 0.1381 - val_accuracy: 0.9343 - val_loss: 0.1969
# Epoch 30/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 13s 31ms/step - accuracy: 0.
print(f"{'Test accuracy':<30} {nn_acc:>12.4f} {cnn_acc:>12.4f}")
print(f"{'Test loss':<30} {nn_loss:>12.4f} {cnn_loss:>12.4f}")
print("="*60)
# Out:
# ============================================================
#   COMPARISON SUMMARY
# ============================================================
# Metric                           Regular NN          CNN
# --------------------------------------------------------
# Trainable parameters                567,434      436,586
# Training time (s)                     161.6       1800.2
# Test accuracy                        0.9002       0.9389
# Test loss                            0.3808       0.2364
# ============================================================

# %%
# ──────────────────────────────────────────────
#  6.  Training curves
# ──────────────────────────────────────────────
fig = plt.figure(figsize=(15, 10))
fig.suptitle("CNN vs. Regular Neural Network — Training Comparison\n(CIFAR-10)",
             fontsize=15, fontweight="bold", y=1.01)

gs = gridspec.GridSpec(2, 2, figure=fig, hspace=0.4, wspace=0.35)

# Accuracy — train
ax1 = fig.add_subplot(gs[0, 0])
ax1.plot(nn_history.history["accuracy"],  label="NN  train", color="#E07B54", lw=2)
ax1.plot(cnn_history.history["accuracy"], label="CNN train", color="#4C72B0", lw=2)
ax1.set_title("Training Accuracy")
ax1.set_xlabel("Epoch"); ax1.set_ylabel("Accuracy")
ax1.legend(); ax1.grid(alpha=0.3)

# Accuracy — validation
ax2 = fig.add_subplot(gs[0, 1])
ax2.plot(nn_history.history["val_accuracy"],  label="NN  val", color="#E07B54", lw=2, linestyle="--")
ax2.plot(cnn_history.history["val_accuracy"], label="CNN val", color="#4C72B0", lw=2, linestyle="--")
ax2.set_title("Validation Accuracy")
ax2.set_xlabel("Epoch"); ax2.set_ylabel("Accuracy")
ax2.legend(); ax2.grid(alpha=0.3)

# Loss — train
ax3 = fig.add_subplot(gs[1, 0])
ax3.plot(nn_history.history["loss"],  label="NN  train", color="#E07B54", lw=2)
ax3.plot(cnn_history.history["loss"], label="CNN train", color="#4C72B0", lw=2)
ax3.set_title("Training Loss")
ax3.set_xlabel("Epoch"); ax3.set_ylabel("Loss")
ax3.legend(); ax3.grid(alpha=0.3)

# Loss — validation
ax4 = fig.add_subplot(gs[1, 1])
ax4.plot(nn_history.history["val_loss"],  label="NN  val", color="#E07B54", lw=2, linestyle="--")
ax4.plot(cnn_history.history["val_loss"], label="CNN val", color="#4C72B0", lw=2, linestyle="--")
ax4.set_title("Validation Loss")
ax4.set_xlabel("Epoch"); ax4.set_ylabel("Loss")
ax4.legend(); ax4.grid(alpha=0.3)

plt.savefig("training_curves.png", dpi=120, bbox_inches="tight")
plt.show()
print("\n📊  Training curves saved → training_curves.png")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[12], line 42
#      38 ax4.set_title("Validation Loss")
#      39 ax4.set_xlabel("Epoch"); ax4.set_ylabel("Loss")
#      40 ax4.legend(); ax4.grid(alpha=0.3)
#      41
# ---> 42 plt.savefig("training_curves.png", dpi=120, bbox_inches="tight")
#      43 plt.show()
#      44 print("\n📊  Training curves saved → training_curves.png")
#      45
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\pyplot.py:1346, in savefig(fname, **kwargs)
#    1343 fig = gcf()
#    1344 # savefig default implementation has no return, so mypy is unhappy
#    1345 # presumably this is here because subclasses can return?
# -> 1346 res = fig.savefig(fname, **kwargs)  # type: ignore[func-returns-value]
#    1347 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1348 return res
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\figure.py:3515, in Figure.savefig(self, fname, transparent, **kwargs)
#    3513     for ax in self.axes:
#    3514         _recursively_make_axes_transparent(stack, ax)
# -> 3515 self.canvas.print_figure(fname, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\backend_bases.py:2281, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2277 try:
#    2278     # _get_renderer may change the figure dpi (as vector formats
#    2279     # force the figure dpi to 72), so we need to set it again here.
#    2280     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2281         result = print_method(
#    2282             filename,
#    2283             facecolor=facecolor,
#    2284             edgecolor=edgecolor,
#    2285             orientation=orientation,
#    2286             bbox_inches_restore=_bbox_inches_restore,
#    2287             **kwargs)
#    2288 finally:
#    2289     if bbox_inches and restore_bbox:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\backend_bases.py:2138, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2134     optional_kws = {  # Passed by print_figure for other renderers.
#    2135         "dpi", "facecolor", "edgecolor", "orientation",
#    2136         "bbox_inches_restore"}
#    2137     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2138     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2139         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2140 else:  # Let third-parties do as they see fit.
#    2141     print_method = meth
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\backends\backend_agg.py:537, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     490 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     491     """
#     492     Write the figure to a PNG file.
#     493
#    (...)    535         *metadata*, including the default 'Software' key.
#     536     """
# --> 537     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\backends\backend_agg.py:486, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     481 """
#     482 Draw the canvas, then save it using `.image.imsave` (to which
#     483 *pil_kwargs* and *metadata* are forwarded).
#     484 """
#     485 FigureCanvasAgg.draw(self)
# --> 486 mpl.image.imsave(
#     487     filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     488     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\image.py:1722, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1720 pil_kwargs.setdefault("format", format)
#    1721 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1722 image.save(fname, **pil_kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\PIL\Image.py:2708, in Image.save(self, fp, format, **params)
#    2706         fp = builtins.open(filename, "r+b")
#    2707     else:
# -> 2708         fp = builtins.open(filename, "w+b")
#    2709 else:
#    2710     fp = cast(IO[bytes], fp)
#
# PermissionError: [Errno 13] Permission denied: 'training_curves.png'

# %%
# ──────────────────────────────────────────────
#  7.  Per-class prediction comparison
# ──────────────────────────────────────────────
nn_preds  = np.argmax(nn_model.predict(x_test,  verbose=0), axis=1)
cnn_preds = np.argmax(cnn_model.predict(x_test, verbose=0), axis=1)
true_labels = y_test.flatten()

nn_per_class  = [np.mean(nn_preds[true_labels == c]  == c) for c in range(NUM_CLASSES)]
cnn_per_class = [np.mean(cnn_preds[true_labels == c] == c) for c in range(NUM_CLASSES)]

x = np.arange(NUM_CLASSES)
width = 0.38

fig, ax = plt.subplots(figsize=(13, 5))
bars1 = ax.bar(x - width/2, nn_per_class,  width, label="Regular NN", color="#E07B54", alpha=0.85)
bars2 = ax.bar(x + width/2, cnn_per_class, width, label="CNN",        color="#4C72B0", alpha=0.85)
ax.set_xticks(x)
ax.set_xticklabels(CLASS_NAMES, rotation=30, ha="right")
ax.set_ylabel("Accuracy")
ax.set_title("Per-Class Test Accuracy — Regular NN vs. CNN", fontsize=13, fontweight="bold")
ax.legend(); ax.grid(axis="y", alpha=0.3)
ax.set_ylim(0, 1)

for bar in bars1:
    ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.01,
            f"{bar.get_height():.2f}", ha="center", va="bottom", fontsize=7)
for bar in bars2:
    ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.01,
            f"{bar.get_height():.2f}", ha="center", va="bottom", fontsize=7)

plt.tight_layout()
plt.savefig("per_class_accuracy.png", dpi=120)
plt.show()
print("📊  Per-class accuracy chart saved → per_class_accuracy.png")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[13], line 32
#      28     ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.01,
#      29             f"{bar.get_height():.2f}", ha="center", va="bottom", fontsize=7)
#      30
#      31 plt.tight_layout()
# ---> 32 plt.savefig("per_class_accuracy.png", dpi=120)
#      33 plt.show()
#      34 print("📊  Per-class accuracy chart saved → per_class_accuracy.png")
#      35
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\pyplot.py:1346, in savefig(fname, **kwargs)
#    1343 fig = gcf()
#    1344 # savefig default implementation has no return, so mypy is unhappy
#    1345 # presumably this is here because subclasses can return?
# -> 1346 res = fig.savefig(fname, **kwargs)  # type: ignore[func-returns-value]
#    1347 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1348 return res
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\figure.py:3515, in Figure.savefig(self, fname, transparent, **kwargs)
#    3513     for ax in self.axes:
#    3514         _recursively_make_axes_transparent(stack, ax)
# -> 3515 self.canvas.print_figure(fname, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\backend_bases.py:2281, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2277 try:
#    2278     # _get_renderer may change the figure dpi (as vector formats
#    2279     # force the figure dpi to 72), so we need to set it again here.
#    2280     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2281         result = print_method(
#    2282             filename,
#    2283             facecolor=facecolor,
#    2284             edgecolor=edgecolor,
#    2285             orientation=orientation,
#    2286             bbox_inches_restore=_bbox_inches_restore,
#    2287             **kwargs)
#    2288 finally:
#    2289     if bbox_inches and restore_bbox:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\backend_bases.py:2138, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2134     optional_kws = {  # Passed by print_figure for other renderers.
#    2135         "dpi", "facecolor", "edgecolor", "orientation",
#    2136         "bbox_inches_restore"}
#    2137     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2138     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2139         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2140 else:  # Let third-parties do as they see fit.
#    2141     print_method = meth
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\backends\backend_agg.py:537, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     490 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     491     """
#     492     Write the figure to a PNG file.
#     493
#    (...)    535         *metadata*, including the default 'Software' key.
#     536     """
# --> 537     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\backends\backend_agg.py:486, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     481 """
#     482 Draw the canvas, then save it using `.image.imsave` (to which
#     483 *pil_kwargs* and *metadata* are forwarded).
#     484 """
#     485 FigureCanvasAgg.draw(self)
# --> 486 mpl.image.imsave(
#     487     filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     488     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\image.py:1722, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1720 pil_kwargs.setdefault("format", format)
#    1721 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1722 image.save(fname, **pil_kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\PIL\Image.py:2708, in Image.save(self, fp, format, **params)
#    2706         fp = builtins.open(filename, "r+b")
#    2707     else:
# -> 2708         fp = builtins.open(filename, "w+b")
#    2709 else:
#    2710     fp = cast(IO[bytes], fp)
#
# PermissionError: [Errno 13] Permission denied: 'per_class_accuracy.png'

# %%
# ──────────────────────────────────────────────
#  8.  Show random predictions side-by-side
# ──────────────────────────────────────────────
sample_idx = np.random.choice(len(x_test), 12, replace=False)
fig, axes = plt.subplots(2, 6, figsize=(16, 6))
fig.suptitle("Random Predictions — same image, different model predictions (green=correct, red=wrong)", fontsize=12, fontweight="bold")

for col, idx in enumerate(sample_idx):
    true     = CLASS_NAMES[true_labels[idx]]
    nn_pred  = CLASS_NAMES[nn_preds[idx]]
    cnn_pred = CLASS_NAMES[cnn_preds[idx]]

    # col 0-5 → top row (NN) and bottom row (CNN) use the same column index
    # sample_idx has 12 items; map items 0-5 to cols 0-5, items 6-11 also to cols 0-5
    c = col % 6   # actual axes column (always 0-5)
    r = col // 6  # which pair-row: 0 = NN top / CNN bottom, 1 = second pair (not used here)

    ax_top = axes[0, c]
    ax_bot = axes[1, c]

    ax_top.imshow(x_test[idx].squeeze(), cmap="gray")
    top_colour = "green" if nn_pred == true else "red"
    ax_top.set_title(f"NN: {nn_pred}", color=top_colour, fontsize=8, fontweight="bold")
    ax_top.set_xlabel(f"True: {true}", fontsize=7)
    ax_top.axis("off")

    ax_bot.imshow(x_test[idx].squeeze(), cmap="gray")
    bot_colour = "green" if cnn_pred == true else "red"
    ax_bot.set_title(f"CNN: {cnn_pred}", color=bot_colour, fontsize=8, fontweight="bold")
    ax_bot.axis("off")

    if col == 5:   # only iterate the first 6 samples (one per column)
        break

axes[0, 0].set_ylabel("Regular NN", fontsize=11, fontweight="bold", color="#E07B54", labelpad=8)
axes[1, 0].set_ylabel("CNN",        fontsize=11, fontweight="bold", color="#1D9E75", labelpad=8)

plt.tight_layout()
plt.savefig("sample_predictions.png", dpi=120)
plt.show()
print("📊  Sample predictions saved → sample_predictions.png")

print("\n🎓  Demo complete!  Key takeaways:")
print("   • The CNN preserves spatial structure → higher accuracy.")
print("   • The Regular NN treats every pixel independently → misses patterns.")
print("   • CNNs often use *fewer* parameters yet achieve *better* results.")
print("   • Both models improve with more epochs and data augmentation.\n")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[18], line 39
#      35 axes[0, 0].set_ylabel("Regular NN", fontsize=11, fontweight="bold", color="#E07B54", labelpad=8)
#      36 axes[1, 0].set_ylabel("CNN",        fontsize=11, fontweight="bold", color="#1D9E75", labelpad=8)
#      37
#      38 plt.tight_layout()
# ---> 39 plt.savefig("sample_predictions.png", dpi=120)
#      40 plt.show()
#      41 print("📊  Sample predictions saved → sample_predictions.png")
#      42
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\pyplot.py:1346, in savefig(fname, **kwargs)
#    1343 fig = gcf()
#    1344 # savefig default implementation has no return, so mypy is unhappy
#    1345 # presumably this is here because subclasses can return?
# -> 1346 res = fig.savefig(fname, **kwargs)  # type: ignore[func-returns-value]
#    1347 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1348 return res
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\figure.py:3515, in Figure.savefig(self, fname, transparent, **kwargs)
#    3513     for ax in self.axes:
#    3514         _recursively_make_axes_transparent(stack, ax)
# -> 3515 self.canvas.print_figure(fname, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\backend_bases.py:2281, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2277 try:
#    2278     # _get_renderer may change the figure dpi (as vector formats
#    2279     # force the figure dpi to 72), so we need to set it again here.
#    2280     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2281         result = print_method(
#    2282             filename,
#    2283             facecolor=facecolor,
#    2284             edgecolor=edgecolor,
#    2285             orientation=orientation,
#    2286             bbox_inches_restore=_bbox_inches_restore,
#    2287             **kwargs)
#    2288 finally:
#    2289     if bbox_inches and restore_bbox:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\backend_bases.py:2138, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2134     optional_kws = {  # Passed by print_figure for other renderers.
#    2135         "dpi", "facecolor", "edgecolor", "orientation",
#    2136         "bbox_inches_restore"}
#    2137     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2138     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2139         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2140 else:  # Let third-parties do as they see fit.
#    2141     print_method = meth
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\backends\backend_agg.py:537, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     490 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     491     """
#     492     Write the figure to a PNG file.
#     493
#    (...)    535         *metadata*, including the default 'Software' key.
#     536     """
# --> 537     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\backends\backend_agg.py:486, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     481 """
#     482 Draw the canvas, then save it using `.image.imsave` (to which
#     483 *pil_kwargs* and *metadata* are forwarded).
#     484 """
#     485 FigureCanvasAgg.draw(self)
# --> 486 mpl.image.imsave(
#     487     filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     488     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\image.py:1722, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1720 pil_kwargs.setdefault("format", format)
#    1721 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1722 image.save(fname, **pil_kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\PIL\Image.py:2708, in Image.save(self, fp, format, **params)
#    2706         fp = builtins.open(filename, "r+b")
#    2707     else:
# -> 2708         fp = builtins.open(filename, "w+b")
#    2709 else:
#    2710     fp = cast(IO[bytes], fp)
#
# PermissionError: [Errno 13] Permission denied: 'sample_predictions.png'
